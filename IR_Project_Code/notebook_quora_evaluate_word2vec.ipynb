# %%
import pandas as pd
from matching import search, search_word2vec 
from dataset_cleaner import clean_process_text
from gensim.models import Word2Vec
import numpy as np
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Firas
# [nltk_data]     ka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Firas
# [nltk_data]     ka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Firas
# [nltk_data]     ka\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#antique word2vec
word2vec_model = Word2Vec.load("qu_word2vec.model")
doc_vectors = np.load("qu_doc_vectors_tfidf_weighted.npy")
dataset = pd.read_csv("D:/IR_data/data/quora/docs.csv", usecols=[0, 1])
qrels_file = "D:/IR_Data/data/quora/qrels.csv"
queries_file = "D:/IR_data/data/quora/queries.csv"

# %%
def get_relevant_id_from_qrel_v2(min_rel_val, query_id, csv_file):
    relevant_ids = set()  
    relevance_scores = {}
    
    try:
        df_qrels = pd.read_csv(csv_file, names=['query_id', 'doc_id', 'relevance'])
        
        df_qrels['query_id'] = df_qrels['query_id'].astype(str).str.strip()
        df_qrels['doc_id'] = df_qrels['doc_id'].astype(str).str.strip()
        df_qrels['relevance'] = pd.to_numeric(df_qrels['relevance'], errors='coerce')
        
        query_qrels = df_qrels[df_qrels['query_id'] == query_id]
        
        if query_qrels.empty:
            print(f"Warning: No qrels found for query {query_id}")
            return list(relevant_ids), relevance_scores
        
        for _, row in query_qrels.iterrows():
            doc_id = row['doc_id']
            rel_val = row['relevance']
            
            if pd.isna(rel_val):
                continue
                
            rel_val = int(rel_val)
            relevance_scores[doc_id] = rel_val
            
            if rel_val >= min_rel_val:
                relevant_ids.add(doc_id)
        
        print(f"Debug - Query {query_id}: Found {len(relevant_ids)} relevant docs, {len(relevance_scores)} total scores")
        print(f"Debug - Relevance values: {sorted(set(relevance_scores.values()))}")
        
        return list(relevant_ids), relevance_scores
        
    except Exception as e:
        print(f"Error reading qrels file: {e}")
        return [], {}

# %%
def precision_at_k(retrieved_docs, relevant_docs, relevance_scores, k):
    relevant_in_top_k = sum(1 for doc in retrieved_docs[:k] if doc in relevant_docs)
    return relevant_in_top_k / k

def calculate_recall(min_rel_val, retrieved_docs, relevant_docs, relevance_scores):
    relevant_retrieved = sum(1 for doc in retrieved_docs if doc in relevant_docs and relevance_scores.get(doc,0) > 0)
    total_relevant = sum(1 for rel in relevance_scores.values() if rel > 0)
    return relevant_retrieved / total_relevant if total_relevant > 0 else 0

def average_precision_at_k(retrieved_docs, relevant_docs, relevance_scores, k):
    precision_sum = 0.0
    relevant_count = 0
    for i in range(min(k, len(retrieved_docs))):
        if retrieved_docs[i] in relevant_docs:
            relevant_count += 1
            precision_sum += precision_at_k(retrieved_docs, relevant_docs, relevance_scores, i + 1)
    return precision_sum / relevant_count if relevant_count > 0 else 0

def reciprocal_rank_at_k(min_rel_val, retrieved_docs, relevant_docs, relevance_scores, k=10):
    for i, doc in enumerate(retrieved_docs[:k]):
        if doc in relevant_docs and relevance_scores.get(doc, 0) >= min_rel_val:
            return 1 / (i + 1)
    return 0

# %%
df_queries = pd.read_csv(queries_file, encoding='utf-8', usecols=[0, 1], names=["query_id", "text"], header=0)

results = []
ap_list = []
mrr_list = []
k = 10
min_rel_val = 1

for idx, row in df_queries.iterrows():
    query_id = str(row["query_id"]).strip()
    query = str(row["text"]).strip()

    if not query:
        continue
    
    # pr_query = clean_process_text(query)

    top_ids, top_docs = search_word2vec(query, word2vec_model, doc_vectors, dataset, 10, 100)

    relevant_docs, relevance_scores = get_relevant_id_from_qrel_v2(min_rel_val, query_id, qrels_file)
    relevant_docs = [int(doc_id) for doc_id in relevant_docs]
    relevance_scores = {int(k): v for k, v in relevance_scores.items()}

    p = precision_at_k(top_ids, relevant_docs, relevance_scores, k)
    r = calculate_recall(min_rel_val, top_ids, relevant_docs, relevance_scores)
    ap = average_precision_at_k(top_ids, relevant_docs, relevance_scores, k)
    rr = reciprocal_rank_at_k(min_rel_val, top_ids, relevant_docs, relevance_scores, k)

    results.append({
        "Query ID": query_id,
        "Precision@10": p * 100,
        "Recall@10": r * 100,
        "AP@10": ap * 100,
        "RR@10": rr
    })

    ap_list.append(ap)
    mrr_list.append(rr)
# Out:
# Debug - Query 318: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 378: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 379: Found 5 relevant docs, 5 total scores
# Debug - Relevance values: [1]
# Debug - Query 399: Found 28 relevant docs, 28 total scores
# Debug - Relevance values: [1]
# Debug - Query 420: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 540: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 548: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 609: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 744: Found 10 relevant docs, 10 total scores
# Debug - Relevance values: [1]
# Debug - Query 784: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 858: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 975: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 1079: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 1088: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 1164: Found 7 relevant docs, 7 total scores
# Debug - Relevance values: [1]
# Debug - Query 1166: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 1248: Found 16 relevant docs, 16 total scores
# Debug - Relevance values: [1]
# Debug - Query 1350: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 1453: Found 3 relevant docs, 3 total scores
# Debug - Relevance values: [1]
# Debug - Query 1578: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 1803: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 1956: Found 6 relevant docs, 6 total scores
# Debug - Relevance values: [1]
# Debug - Query 1992: Found 7 relevant docs, 7 total scores
# Debug - Relevance values: [1]
# Debug - Query 2004: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2145: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2254: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2429: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2615: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2658: Found 5 relevant docs, 5 total scores
# Debug - Relevance values: [1]
# Debug - Query 2661: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2678: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2757: Found 3 relevant docs, 3 total scores
# Debug - Relevance values: [1]
# Debug - Query 2785: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2791: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 2822: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 2824: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 3017: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 3076: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 3322: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 3459: Found 14 relevant docs, 14 total scores
# Debug - Relevance values: [1]
# Debug - Query 3521: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 3581: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 3594: Found 4 relevant docs, 4 total scores
# Debug - Relevance values: [1]
# Debug - Query 3612: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 3796: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 3959: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 4105: Found 10 relevant docs, 10 total scores
# Debug - Relevance values: [1]
# Debug - Query 4298: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 4356: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 4584: Found 4 relevant docs, 4 total scores
# Debug - Relevance values: [1]
# Debug - Query 4874: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 4974: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 5040: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 5162: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 5319: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 5498: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 5516: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 5647: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 5799: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 5851: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 6021: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 6022: Found 3 relevant docs, 3 total scores
# Debug - Relevance values: [1]
# Debug - Query 6055: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 6209: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 6244: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 6253: Found 9 relevant docs, 9 total scores
# Debug - Relevance values: [1]
# Debug - Query 6276: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 6483: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 6588: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 6786: Found 4 relevant docs, 4 total scores
# Debug - Relevance values: [1]
# Debug - Query 6936: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 6957: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7105: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7222: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7301: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7319: Found 7 relevant docs, 7 total scores
# Debug - Relevance values: [1]
# Debug - Query 7372: Found 4 relevant docs, 4 total scores
# Debug - Relevance values: [1]
# Debug - Query 7396: Found 4 relevant docs, 4 total scores
# Debug - Relevance values: [1]
# Debug - Query 7463: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7614: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7616: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 7822: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7841: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 7957: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 7988: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 8055: Found 4 relevant docs, 4 total scores
# Debug - Relevance values: [1]
# Debug - Query 8306: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 8456: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 8458: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 8482: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 8808: Found 12 relevant docs, 12 total scores
# Debug - Relevance values: [1]
# Debug - Query 8810: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 8831: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 8950: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 9214: Found 3 relevant docs, 3 total scores
# Debug - Relevance values: [1]
# Debug - Query 9294: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 9312: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 9340: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 9376: Found 5 relevant docs, 5 total scores
# Debug - Relevance values: [1]
# Debug - Query 9602: Found 3 relevant docs, 3 total scores
# Debug - Relevance values: [1]
# Debug - Query 9615: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 9658: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 9733: Found 13 relevant docs, 13 total scores
# Debug - Relevance values: [1]
# Debug - Query 9889: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 9965: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10024: Found 22 relevant docs, 22 total scores
# Debug - Relevance values: [1]
# Debug - Query 10113: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10155: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10188: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10453: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10648: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10722: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10810: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 10889: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 10910: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 11009: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 11037: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 11167: Found 50 relevant docs, 50 total scores
# Debug - Relevance values: [1]
# Debug - Query 11221: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 11227: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 11302: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 11591: Found 14 relevant docs, 14 total scores
# Debug - Relevance values: [1]
# Debug - Query 11726: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query
Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 515431: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 515558: Found 3 relevant docs, 3 total scores
# Debug - Relevance values: [1]
# Debug - Query 515621: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 516314: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 516412: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 516423: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 516457: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 516489: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 516670: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 516993: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 517085: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 517338: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 517508: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 517547: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 517627: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 517799: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518241: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518260: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518395: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518410: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518434: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518493: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518761: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518765: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518777: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 518938: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 519085: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 519420: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 519757: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 519776: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 519825: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 519911: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 520346: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520348: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 520375: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520489: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520578: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520642: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520694: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520895: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520939: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 520991: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 521153: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 521182: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 521198: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 521319: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 521338: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 521592: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 522315: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 522392: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 522606: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 522689: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 522891: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 522992: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523183: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523290: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523388: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523441: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523736: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523749: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523760: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523772: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523867: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 523941: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 524137: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524353: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524494: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524667: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524738: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524821: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524942: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524980: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 524999: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525139: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525152: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525409: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525563: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525682: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525698: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525723: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525863: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525902: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 525974: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 526630: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 526846: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 526881: Found 2 relevant docs, 2 total scores
# Debug - Relevance values: [1]
# Debug - Query 526926: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 526996: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 527522: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 527543: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 527587: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528157: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528309: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528328: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528451: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528497: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528566: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528741: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 528846: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529030: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529418: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529567: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529589: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529647: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529664: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529938: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529963: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 529977: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 530185: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 530790: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 530820: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 530921: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 530949: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 531034: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 531177: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 531285: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 531584: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 531717: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 531871: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532033: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532048: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532064: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532210: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532215: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532267: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532508: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532557: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 532682: Found 3 relevant docs, 3 total scores
# Debug - Relevance values: [1]
# Debug - Query 533284: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533286: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533329: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533455: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533574: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533590: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533673: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533805: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 533826: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 534403: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 534612: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 534840: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 535273: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 535491: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 535506: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 535622: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 535839: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 536078: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 536145: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 536183: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 536238: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 536328: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 536474: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537013: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537159: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537230: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537329: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537374: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537736: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537788: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]
# Debug - Query 537790: Found 1 relevant docs, 1 total scores
# Debug - Relevance values: [1]

# %%
df_results = pd.DataFrame(results)
df_results.head(20)
# Out:
#    Query ID  Precision@10   Recall@10       AP@10     RR@10
# 0       318           0.0    0.000000    0.000000  0.000000
# 1       378           0.0    0.000000    0.000000  0.000000
# 2       379          40.0   80.000000   87.500000  1.000000
# 3       399          90.0   32.142857   92.826279  1.000000
# 4       420          10.0  100.000000   33.333333  0.333333
# 5       540          10.0   50.000000  100.000000  1.000000
# 6       548          10.0  100.000000  100.000000  1.000000
# 7       609          20.0  100.000000   58.333333  0.500000
# 8       744          40.0   40.000000   80.416667  1.000000
# 9       784          10.0   50.000000  100.000000  1.000000
# 10      858           0.0    0.000000    0.000000  0.000000
# 11      975          10.0  100.000000   33.333333  0.333333
# 12     1079          10.0   50.000000   14.285714  0.142857
# 13     1088          10.0   50.000000  100.000000  1.000000
# 14     1164          10.0   14.285714  100.000000  1.000000
# 15     1166          10.0  100.000000   20.000000  0.200000
# 16     1248          70.0   43.750000   77.981859  1.000000
# 17     1350           0.0    0.000000    0.000000  0.000000
# 18     1453          10.0   33.333333   33.333333  0.333333
# 19     1578          10.0  100.000000   10.000000  0.100000

# %%
map_score = sum(ap_list) / len(ap_list) * 100
mrr_score = sum(mrr_list) / len(mrr_list) * 100

print(f"📊 Final MAP: {map_score:.2f}%")
print(f"📊 Final MRR@10: {mrr_score:.2f}%")
# Out:
# 📊 Final MAP: 26.62%
# 📊 Final MRR@10: 27.10%
